# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Data (extracted from the image)
data = {
    'Category': [
        'Baby Food', 'Beverages', 'Cereal', 'Clothes', 'Cosmetics', 'Fruits',
        'Household', 'Meat', 'Office Supplies', 'Personal Care', 'Snacks', 'Vegetables'
    ],
    'Offline Revenue': [
        5383395696, 980243452.5, 4316312327, 2310163573, 9214318774, 190069752.4,
        13682927822, 8866361347, 13802583498, 1690744750, 3198420715, 3114790010
    ],
    'Online Revenue': [
        5315802658, 989605954.3, 4375421456, 2254837950, 9115065886, 1905068832.7,
        14022877411, 8745831972, 13739525931, 1702205625, 3164026742, 3240930024
    ],
    'Offline Profit': [
        2021514852, 323511327, 1858931011, 1552511098, 3664441000, 490962569.3,
        3393349644, 1202104504, 2675905110, 518415067.2, 1155858686, 1276364360
    ],
    'Online Profit': [
        1996133041, 326601248.6, 1884387879, 1515330336, 3624965545, 492271575.4,
        3477619652, 1185730489, 2663628738, 522020148.7, 1143429247, 1328053437
    ]
}

df = pd.DataFrame(data)

# Step 2: Plot (side-by-side comparison)
plt.figure(figsize=(14, 7))
sns.set_style("whitegrid")

# Bar chart
bar_width = 0.35
x = range(len(df))

plt.bar(x, df['Offline Profit'], width=bar_width, label='Offline Profit', color='#9ecae1')
plt.bar([i + bar_width for i in x], df['Online Profit'], width=bar_width, label='Online Profit', color='#6baed6')

# Axis and label tweaks
plt.xticks([i + bar_width / 2 for i in x], df['Category'], rotation=45, ha='right')
plt.ylabel('Profit ($)')
plt.title('🛍️ Walmart Category-Wise Profit: Offline vs Online Channels')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-22-d81ccdbb2f4c>:47: UserWarning:
#
# Glyph 128717 (\N{SHOPPING BAGS}) missing from font(s) DejaVu Sans.
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning:
#
# Glyph 128717 (\N{SHOPPING BAGS}) missing from font(s) DejaVu Sans.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Dataset from your image
data = {
    'Year': ['2020', '2021', '2022', '2023', '2024'],
    'Revenue ($M)': [523964, 559151, 572754, 611289, 648125],
    'Employee Count': [2200000, 2300000, 2300000, 2100000, 2100000],
    'Operating Income ($M)': [20568, 22548, 25942, 20428, 27012],
    'Gross Profit ($M)': [129359, 138836, 143754, 147568, 157983],
    'SG&A Expenses ($M)': [108791, 116288, 117812, 127140, 130971],
    'Current Ratio': [0.84, 0.95, 0.87, 0.85, 0.85]
}

df = pd.DataFrame(data)
df.set_index('Year', inplace=True)

# Step 2: Normalize for heatmap scaling (optional)
df_scaled = df.copy()
for col in df.columns:
    df_scaled[col] = (df[col] - df[col].min()) / (df[col].max() - df[col].min())

# Step 3: Heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(df_scaled.T, annot=df.T, fmt=".0f", cmap='Blues', linewidths=0.5, cbar=False)

plt.title("🔥 Walmart Strategic Metric Heatmap (2020–2024)", fontsize=14)
plt.ylabel("Key Metrics")
plt.xlabel("Year")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-26-e1481b1f8b6c>:32: UserWarning:
#
# Glyph 128293 (\N{FIRE}) missing from font(s) DejaVu Sans.
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning:
#
# Glyph 128293 (\N{FIRE}) missing from font(s) DejaVu Sans.
